# %%
import pandas as pd
import json
import datetime 
import time
import calendar
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from math import factorial

# %%
df = pd.read_csv('cal_tweet.csv')

# %%
df = df.drop(axis=1, columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#                source                                               text  \
# 0  TWITTER FOR IPHONE  ACCORDING TO NBC NEWS VOTERS NATIONWIDE DISAPP...
# 1  TWITTER FOR IPHONE  IN ALL FAIRNESS NANCY PELOSI DESERVES TO BE CH...
# 2  TWITTER FOR IPHONE  IF THE DEMOCRATS THINK THEY ARE GOING TO WASTE...
# 3  TWITTER FOR IPHONE  TO ANY OF THE PUNDITS OR TALKING HEADS THAT DO...
# 4  TWITTER FOR IPHONE  THOSE THAT WORKED WITH ME IN THIS INCREDIBLE M...
#
#    retweet_count  favorite_count  is_retweet        id_str        date  \
# 0        28199.0        122357.0       False  1.060190e+18  2018-11-07
# 1        18157.0         88740.0       False  1.060160e+18  2018-11-07
# 2        45878.0        177925.0       False  1.060160e+18  2018-11-07
# 3        29074.0        138690.0       False  1.060150e+18  2018-11-07
# 4        24165.0        109847.0       False  1.060140e+18  2018-11-07
#
#        time  hour  week time_start  time_end duration    listed_title  \
# ...

# %%
clean_df = pd.read_csv('trump_tweets_clean.csv')

# %%
clean_df = clean_df.drop(axis=1, columns=['Unnamed: 0'])

# %%
clean_df.date = pd.to_datetime(clean_df.date)

# %%
clean_df[clean_df.date=='2017-06-22'] #trumps twitter storm 2017
# Out:
#                   source                                               text  \
# 7289  Twitter for iPhone  We're all thinking of you @SteveScalise! #Team...
# 7290  Twitter for iPhone  Together we are going to MAKE AMERICA GREAT AG...
# 7291  Twitter for iPhone  I am very supportive of the Senate #Healthcare...
# 7292  Twitter for iPhone  Mexico was just ranked the second deadliest co...
# 7293  Twitter for iPhone  As promised our campaign against the MS-13 gan...
# 7294  Twitter for iPhone  ...whether there are "tapes" or recordings of ...
# 7295  Twitter for iPhone  With all of the recently reported electronic s...
# 7296  Twitter for iPhone  I certainly hope the Democrats do not force Na...
# 7297  Twitter for iPhone  ...Why did the DNC REFUSE to turn over its Ser...
# 7298  Twitter for iPhone  ...Why did Democratic National Committee turn ...
# 7299  Twitter for iPhone  By the way if Russia was working so hard on th...
# ...

# %%
poll_df = pd.read_csv('approval_topline.csv')

# %%
poll = poll_df[['modeldate','approve_estimate','disapprove_estimate']]

# %%
poll.modeldate = pd.to_datetime(poll.modeldate)

poll = poll.rename(index=str, columns={'modeldate': 'date'})
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
clean_df.merge(poll, how='left', on='date')
# Out:
#                      source  \
# 0        Twitter for iPhone
# 1        Twitter for iPhone
# 2        Twitter for iPhone
# 3      Twitter Media Studio
# 4      Twitter Media Studio
# 5      Twitter Media Studio
# 6        Twitter for iPhone
# 7        Twitter for iPhone
# 8        Twitter for iPhone
# 9        Twitter for iPhone
# 10       Twitter for iPhone
# 11       Twitter for iPhone
# 12       Twitter for iPhone
# 13       Twitter for iPhone
# 14       Twitter for iPhone
# 15       Twitter for iPhone
# 16       Twitter for iPhone
# 17       Twitter for iPhone
# 18       Twitter for iPhone
# 19       Twitter for iPhone
# 20       Twitter for iPhone
# 21       Twitter for iPhone
# 22       Twitter for iPhone
# 23       Twitter for iPhone
# 24       Twitter for iPhone
# 25       Twitter for iPhone
# 26       Twitter for iPhone
# 27       Twitter for iPhone
# 28       Twitter for iPhone
# 29       Twitter for iPhone
# ...                     ...
# 24273    Twitter for iPhone
# ...
